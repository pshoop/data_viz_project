# %% [markdown]
# # Primary Data Wrangling Notebook for Data Visualization Final Project

# %%
# Import pertinent libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# Provide plotting in-line as needed
# %matplotlib inline

# %%
# create data path for importing data
path = "./data/"

# Join all files in the data path into a list
all_files = glob.glob(os.path.join(path, "*.csv"))

# Create a for loop to extract just the filename (not extension)
# for use in naming dataframes
name_list = []
for file in all_files:
    name_list.append(os.path.splitext(os.path.basename(file))[0])

# %%
# create an empty dictionary to hold all the dataframes
d = {}

# create a for loop to recursively add .csv files to the dictionary as dataframes
for idx, val in enumerate(all_files):
    d[name_list[idx]] = pd.read_csv(val)

# %%
# create a series of dictionaries from the 'Categories' dataframe
# These dictionaries will be used to create a larger dataframe
# The reason for this is that the data came from a relational database
# that really didn't need to be relational. Having it as a flat datafram
# makes EDA and data visualization much easier
cats = d['categories'].set_index('id')['cat_name'].to_dict()
cats[-1] = 'Other'
styles = d['styles'].set_index('id')['style_name'].to_dict()
styles[-1] = 'Other'
breweries = d['breweries'].set_index('id')['name'].to_dict()

# Use the dictionaries above to replace the foreign keys in 
# the 'beers' dataframe with their actual values
d['beers'].cat_id.replace(cats, inplace = True)
d['beers'].style_id.replace(styles, inplace = True)
brewery_name_list = list(d['beers'].brewery_id.replace(breweries))

# Use brewery_name_list to create a new column called brewery_name
d['beers']['brewery_name'] = brewery_name_list

# Check our work
d['beers'].head()
# Out:
#    id  brewery_id                    name       cat_id  \
# 0   1         812             Hocus Pocus  Other Style
# 1   2         264       Grimbergen Blonde        Other
# 2   3         779  Widdershins Barleywine        Other
# 3   4         287                 Lucifer        Other
# 4   5        1056                  Bitter        Other
#
#                             style_id  abv               brewery_name
# 0  Light American Wheat Ale or Lager  4.5                  Magic Hat
# 1                              Other  6.7       Brouwerij Alken-Maes
# 2                              Other  9.1  Left Hand Brewing Company
# 3                              Other  8.5         Brouwerij Liefmans
# 4                              Other  4.0           Ridgeway Brewing

# %%
# Merge the 'beers' data frame with the 'breweries_geocode' dataframe.
# In this case, the 'brewery_id' field served as the key for joining
df_beers = d['beers'].merge(d['breweries_geocode'], on = 'brewery_id')

# Drop redundant and uncessary columns
df_beers.drop(columns=['id_x', 'id_y', 'accuracy'], inplace = True)

# Sort values by brewery_id for a cleaner presentation
df_beers.sort_values('brewery_id', inplace = True)

# Check our work
df_beers
# Out:
#       brewery_id                                           name  \
# 5652           1                                     (512) Pale
# 5656           1                                    (512) Bruin
# 5657           1  (512) Whiskey Barrel Aged Double Pecan Porter
# 5658           1                                            One
# 5653           1                                      (512) IPA
# 5655           1                                      (512) ALT
# 5654           1                             (512) Pecan Porter
# 5651           1                                      (512) Wit
# 4727           2                             Amendment Pale Ale
# 4729           2                                 North Star Red
# 4725           2                                Bitter American
# 4724           2                              South Park Blonde
# 4730           2                         General Pippo's Porter
# 4731           2                                        21A IPA
# 4732           2                      Oyster Point Oyster Stout
# 4728           2                                    Potrero ESB
# 4726           2                               Watermelon Wheat
# 4733           2                                      563 Stout
# 4734           2                             Double Trouble IPA
# 4742           3                           Drie Fonteinen Kriek
# 4741           3                                     Oude Geuze
# 3848           4                           Classic Special Brew
# 3849           4                                        JuleÃ¸l
# 3850           4                                      Bock Beer
# 3852           4                                   Gull Classic
# 3851           4                                Genuine Pilsner
# 4904           5                                  Brune (Brown)
# 4905           5                                   Leffe Blonde
# 4667           6                                              8
# 4666           6                                             10
# ...          ...                                            ...
# 2893        1386                                Clearview Light
# 4367        1387                               Blueberry Blonde
# 4368        1387                                Cask Scotch Ale
# 4371        1387                                 White Rock Red
# 4369        1387                               Icehaus Pale Ale
# 4372        1387                                   Golden Wheat
# 4370        1387                                    Oktoberfest
# 4616        1388                         Yuengling Premium Beer
# 4618        1388                            Yuengling Bock Beer
# 4615        1388                          Lord Chesterfield Ale
# 4617        1388                        Yuengling Premium Light
# 4614        1388                        Yuengling Black and Tan
# 4613        1388                               Yuengling Porter
# 4612        1388                          Yuengling Lager Light
# 4611        1388                                Yuengling Lager
# 2787        1389          Yorkshire Terrier Premium Cask Bitter
# 4082        1390                            Grizzly Wulff Wheat
# 5045        1391                                   Onward Stout
# 5044        1391                                 Sly Rye Porter
# 5043        1391                                     Hefeweizen
# 5041        1391                                     Dos Perros
# 5040        1391                                     Hefeweizen
# 5039        1391                                            ESB
# 5038        1391                                   Onward Stout
# 5037        1391                                       Pale Ale
# 5036        1391                                 Sly Rye Porter
# 5035        1391                                     Dos Perros
# 5042        1391                                       Pale Ale
# 5678        1394                                     HotRod Red
# 5679        1394                      Old BullDog Extra Special
#
#                       cat_id                           style_id   abv  \
# 5652      North American Ale            American-Style Pale Ale   5.8
# 5656      North American Ale           American-Style Brown Ale   7.6
# 5657               Irish Ale                             Porter   8.2
# 5658  Belgian and French Ale      Belgian-Style Pale Strong Ale   8.0
# 5653      North American Ale      American-Style India Pale Ale   7.0
# 5655              German Ale     German-Style Brown Ale/Altbier   6.0
# 5654               Irish Ale                             Porter   6.8
# 5651  Belgian and French Ale                Belgian-Style White   5.2
# 4727      North American Ale            American-Style Pale Ale   5.2
# 4729      North American Ale       American-Style Amber/Red Ale   5.8
# 4725             British Ale      Special Bitter or Best Bitter   3.6
# 4724      North American Ale               Golden or Blonde Ale   5.0
# 4730               Irish Ale                             Porter   5.5
# 4731      North American Ale      American-Style India Pale Ale   7.2
# 4732      North American Ale               American-Style Stout   5.9
# 4728             British Ale      Special Bitter or Best Bitter   5.2
# 4726  Belgian and French Ale         Belgian-Style Fruit Lambic   5.5
# 4733      North American Ale               American-Style Stout   5.0
# 4734      North American Ale  Imperial or Double India Pale Ale   9.8
# 4742  Belgian and French Ale         Belgian-Style Fruit Lambic   5.0
# 4741  Belgian and French Ale         Belgian-Style Fruit Lambic   6.0
# 3848    North American Lager               American-Style Lager   0.0
# 3849      North American Ale      Dark American-Belgo-Style Ale   5.9
# 3850            German Lager      Traditional German-Style Bock   5.9
# 3852    North American Lager               American-Style Lager   5.5
# 3851            German Lager              German-Style Pilsener   5.5
# 4904                   Other                              Other   6.8
# 4905      North American Ale               Golden or Blonde Ale   6.6
# 4667  Belgian and French Ale               Belgian-Style Dubbel   8.0
# 4666  Belgian and French Ale               Belgian-Style Tripel  10.0
# ...                      ...                                ...   ...
# 2893                   Other                              Other   0.0
# 4367             Other Style  Light American Wheat Ale or Lager   0.0
# 4368                   Other                              Other   0.0
# 4371      North American Ale       American-Style Amber/Red Ale   0.0
# 4369      North American Ale            American-Style Pale Ale   0.0
# 4372    North American Lager               American-Style Lager   0.0
# 4370            German Lager           German-Style Oktoberfest   0.0
# 4616    North American Lager               American-Style Lager   4.4
# 4618            German Lager      Traditional German-Style Bock   0.0
# 4615      North American Ale            American-Style Pale Ale   5.4
# 4617    North American Lager         American-Style Light Lager   3.5
# 4614                   Other                              Other   4.7
# 4613               Irish Ale                             Porter   4.7
# 4612    North American Lager         American-Style Light Lager   3.4
# 4611    North American Lager               American-Style Lager   4.4
# 2787                   Other                              Other   4.2
# 4082                   Other                              Other   5.3
# 5045      North American Ale               American-Style Stout   3.8
# 5044      North American Ale                             Porter   5.7
# 5043              German Ale      South German-Style Hefeweizen   5.0
# 5041      North American Ale           American-Style Brown Ale   3.5
# 5040              German Ale      South German-Style Hefeweizen   5.0
# 5039             British Ale               Extra Special Bitter   0.0
# 5038      North American Ale               American-Style Stout   3.8
# 5037      North American Ale            American-Style Pale Ale   5.8
# 5036               Irish Ale                             Porter   5.7
# 5035      North American Ale      Dark American-Belgo-Style Ale   3.5
# 5042      North American Ale     American-Style Strong Pale Ale   5.8
# 5678               Irish Ale                Irish-Style Red Ale   6.1
# 5679      North American Ale     American-Style Strong Pale Ale   5.8
#
#                                            brewery_name  latitude  longitude
# 5652                              (512) Brewing Company   30.2234   -97.7697
# 5656                              (512) Brewing Company   30.2234   -97.7697
# 5657                              (512) Brewing Company   30.2234   -97.7697
# 5658                              (512) Brewing Company   30.2234   -97.7697
# 5653                              (512) Brewing Company   30.2234   -97.7697
# 5655                              (512) Brewing Company   30.2234   -97.7697
# 5654                              (512) Brewing Company   30.2234   -97.7697
# 5651                              (512) Brewing Company   30.2234   -97.7697
# 4727                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4729                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4725                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4724                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4730                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4731                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4732                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4728                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4726                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4733                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4734                        21st Amendment Brewery Cafe   37.7825  -122.3930
# 4742  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij   50.7668     4.3081
# 4741  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij   50.7668     4.3081
# 3848                                       Aass Brewery   59.7451    10.2135
# 3849                                       Aass Brewery   59.7451    10.2135
# 3850                                       Aass Brewery   59.7451    10.2135
# 3852                                       Aass Brewery   59.7451    10.2135
# 3851                                       Aass Brewery   59.7451    10.2135
# 4904                                    Abbaye de Leffe   50.2606     4.9122
# 4905                                    Abbaye de Leffe   50.2606     4.9122
# 4667                                Abbaye de Maredsous   50.3093     4.7646
# 4666                                Abbaye de Maredsous   50.3093     4.7646
# ...                                                 ...       ...        ...
# 2893                         Zea Rotisserie and Brewery   29.9386   -90.0760
# 4367                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4368                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4371                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4369                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4372                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4370                       Yegua Creek Brewing - Dallas   32.8210   -96.7848
# 4616                            Yuengling & Son Brewing   40.7000   -76.1747
# 4618                            Yuengling & Son Brewing   40.7000   -76.1747
# 4615                            Yuengling & Son Brewing   40.7000   -76.1747
# 4617                            Yuengling & Son Brewing   40.7000   -76.1747
# 4614                            Yuengling & Son Brewing   40.7000   -76.1747
# 4613                            Yuengling & Son Brewing   40.7000   -76.1747
# 4612                            Yuengling & Son Brewing   40.7000   -76.1747
# 4611                            Yuengling & Son Brewing   40.7000   -76.1747
# 2787                                       York Brewery   53.9571    -1.0905
# 4082                         Yellowstone Valley Brewing   45.7861  -108.4980
# 5045                                      Yazoo Brewing   36.1510   -86.7821
# 5044                                      Yazoo Brewing   36.1510   -86.7821
# 5043                                      Yazoo Brewing   36.1510   -86.7821
# 5041                                      Yazoo Brewing   36.1510   -86.7821
# 5040                                      Yazoo Brewing   36.1510   -86.7821
# 5039                                      Yazoo Brewing   36.1510   -86.7821
# 5038                                      Yazoo Brewing   36.1510   -86.7821
# 5037                                      Yazoo Brewing   36.1510   -86.7821
# 5036                                      Yazoo Brewing   36.1510   -86.7821
# 5035                                      Yazoo Brewing   36.1510   -86.7821
# 5042                                      Yazoo Brewing   36.1510   -86.7821
# 5678                            Aviator Brewing Company   35.6197   -78.8085
# 5679                            Aviator Brewing Company   35.6197   -78.8085
#
# [5680 rows x 8 columns]

# %%
# Output the new 'non-relational' table to a csv file for future EDA/Visualization
df_beers.to_csv('./data/df_beers.csv', index = False)

# %% [markdown]
# # End of Notebook 1
# ### As it turns out, I didn't do much wrangling here - this was primarily cleaning one set of tables to create a master table. More wrangling is done in the Data_Viz notebook. Stay Tuned!
